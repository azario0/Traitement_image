# %%
import cv2 as cv
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Lire 'pour.tif' 
circles = cv.imread("/home/azarmalek/Desktop/Traitement_image/TP4-Opérateurs_Morphologiques/circles.png",0)
flou_test = cv.imread("/home/azarmalek/Desktop/Traitement_image/TP4-Opérateurs_Morphologiques/flou_test.png",0)
formes = cv.imread("/home/azarmalek/Desktop/Traitement_image/TP4-Opérateurs_Morphologiques/formes.png",0)
text = cv.imread("/home/azarmalek/Desktop/Traitement_image/TP4-Opérateurs_Morphologiques/text.png",0)

# %%
from matplotlib import pyplot as plt

# Define our imshow function 
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
image = text
imshow('Original', image)

# Element structurant
kernel = np.ones((5,5), np.uint8)

# Erosion
erosion = cv.erode(image, kernel, iterations = 1)
imshow('Erosion', erosion)

# %%
# Dilation
dilation = cv.dilate(image, kernel, iterations = 1)
imshow('Dilation', dilation)

# %%
# Opening 
opening = cv.morphologyEx(image, cv.MORPH_OPEN, kernel)
imshow('Opening',opening)

# %%
# Closing 
closing = cv.morphologyEx(image, cv.MORPH_CLOSE, kernel)
imshow('Closing',closing)

# %%
line_kernel = np.ones((1, 5), np.uint8)


dilation = cv.dilate(image, line_kernel, iterations=1)

# %%
imshow('Closing',dilation)

# %%
erosion = cv.erode(image, line_kernel, iterations=1)

# %%
imshow('Closing',erosion)

# %%
square = np.ones((5, 5), np.uint8)

# %%
dilation_sq = cv.dilate(image, square, iterations=1)

# %%
imshow('Closing',dilation_sq)

# %%
erosion_sq = cv.erode(image, square, iterations=1)

# %%
imshow('Closing',erosion_sq)
